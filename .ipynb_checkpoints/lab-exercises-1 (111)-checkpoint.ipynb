# %% [markdown]
# # Name: Anderson A. Pepple
# ### Mat No: 20120612203
# ##### email: Anderson.pepple@gmail.com
# ![image.jfif](attachment:image.jfif)

# %% [markdown]
# # EXERCISE 1
# #### A python code to get the difference betweed a given number and 17, if the number is > 17, return double the absolute difference
# ![image.png](attachment:image.png)

# %%
a=float(input("input value:"))
x=a-17
if a>17: 
    b=x*2
    print(b)
else: 
    a<17
    x=a-17
    print(-x)
# Out:
# input value:12
# 5.0

# %% [markdown]
# # EXERCISE 2
# #### a python program to calculate the sum of three given numbers, if the values are equal then return thrice of their sum.
# ![image.png](attachment:image.png)

# %%
a=float(input("input value a:"))
b=float(input("input value b:"))
c=float(input("input value c:"))
if a!=b!=c:
   p=a+b+c
   print (p)
else:
    a=b=c
    r=a+b+c
    q=r*3
    print (q)
# Out:
# input value a:12
# input value b:12
# input value c:12
# 108.0

# %% [markdown]
# # EXERCISE 3
# #### a python program which will return true if the two given integer values are equal or their sum difference is 5
# ![image.png](attachment:image.png)

# %%
a=float(input("input value a:"))
b=float(input("input value b:"))
x=a+b
y=a-b
if a==b:
    print("TRUE")
elif x==5:
    print("TRUE")
elif y==5:
    print("TRUE")
else:
    print("FALSE")
# Out:
# input value a:2
# input value b:23
# FALSE

# %% [markdown]
# ### EXERCISE 4
# #### a python program to sort three integers without using conditional statements and loops
# ![image.png](attachment:image.png)

# %%
a = int(input("enter value "))
b = int(input("enter value "))
c = int(input("enter value "))
d = min(a, b, c)
e = max(a, b, c)
f = (a+b+c) - (d + e)
print("max value is", e, "min value is", d, "mid value is", f)
# Out:
# enter value 12
# enter value 2
# enter value 3
# max value is 12 min value is 2 mid value is 3

# %% [markdown]
# # EXERCISE 5
# #### a python function that takes a positive integer and returbs the sum of the cube of all the positive integers smaller than the specified number
# ![image.png](attachment:image.png)

# %%
a = int(input("input value "))
d = 0

b = range(1,a)
for b in range(1,a):
    c = b**3
    d = d + c
    
print(d)
# Out:
# input value 3
# 9
